# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_vs.csv", sep="\t")
df.head()
# Out:
# C:\Users\infom\AppData\Local\Temp\ipykernel_19188\3365283651.py:1: DtypeWarning: Columns (11,17,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dataset_vs.csv", sep="\t")
#    code                                                url  \
# 0     2  http://world-en.openfoodfacts.org/product/0000...
# 1     3  http://world-en.openfoodfacts.org/product/0000...
# 2     4  http://world-en.openfoodfacts.org/product/0000...
# 3     5  http://world-en.openfoodfacts.org/product/0000...
# 4     6  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1760861583  2025-10-19T08:13:03Z
# 1  openfoodfacts-contributors  1752485388  2025-07-14T09:29:48Z
# 2  openfoodfacts-contributors  1768903196  2026-01-20T09:59:56Z
# 3                 moon-rabbit  1767072228  2025-12-30T05:23:48Z
# 4                 moon-rabbit  1760212975  2025-10-11T20:02:55Z
#
#    last_modified_t last_modified_datetime last_modified_by  last_updated_t  \
# 0       1760861586   2025-10-19T08:13:06Z              NaN      1760861586
# 1       1752485389   2025-07-14T09:29:49Z              NaN      1752485389
# 2       1768903204   2026-01-20T10:00:04Z              NaN      1768903204
# 3       1767072233   2025-12-30T05:23:53Z      moon-rabbit      1767072233
# 4       1760218930   2025-10-11T21:42:10Z         ascharao      1760218930
#
#   last_updated_datetime  ... water-hardness_100g choline_100g  \
# 0  2025-10-19T08:13:06Z  ...                 NaN          NaN
# 1  2025-07-14T09:29:49Z  ...                 NaN          NaN
# 2  2026-01-20T10:00:04Z  ...                 NaN          NaN
# 3  2025-12-30T05:23:53Z  ...                 NaN          NaN
# 4  2025-10-11T21:42:10Z  ...                 NaN          NaN
#
#   phylloquinone_100g beta-glucan_100g inositol_100g carnitine_100g  \
# 0                NaN              NaN           NaN            NaN
# 1                NaN              NaN           NaN            NaN
# 2                NaN              NaN           NaN            NaN
# 3                NaN              NaN           NaN            NaN
# 4                NaN              NaN           NaN            NaN
#
#   sulphate_100g nitrate_100g acidity_100g carbohydrates-total_100g
# 0           NaN          NaN          NaN                      NaN
# 1           NaN          NaN          NaN                      NaN
# 2           NaN          NaN          NaN                      NaN
# 3           NaN          NaN          NaN                      NaN
# 4           NaN          NaN          NaN                      NaN
#
# [5 rows x 215 columns]

# %%
snacks = df[df["categories_tags"].str.contains("Snack", case=False, na=False)]
snacks.head()
# Out:
#     code                                                url  \
# 9     10  http://world-en.openfoodfacts.org/product/0000...
# 12    13  http://world-en.openfoodfacts.org/product/0000...
# 13    15  http://world-en.openfoodfacts.org/product/0000...
# 18    20  http://world-en.openfoodfacts.org/product/0000...
# 20    22  http://world-en.openfoodfacts.org/product/0000...
#
#                        creator   created_t      created_datetime  \
# 9                     jeanbono  1476947941  2016-10-20T07:19:01Z
# 12                   jeff-krab  1553970319  2019-03-30T18:25:19Z
# 13  openfoodfacts-contributors  1523810594  2018-04-15T16:43:14Z
# 18  openfoodfacts-contributors  1536930846  2018-09-14T13:14:06Z
# 20  openfoodfacts-contributors  1614525537  2021-02-28T15:18:57Z
#
#     last_modified_t last_modified_datetime last_modified_by  last_updated_t  \
# 9        1750695017   2025-06-23T16:10:17Z     smoothie-app      1750695017
# 12       1744243884   2025-04-10T00:11:24Z           maldan      1744243884
# 13       1746561377   2025-05-06T19:56:17Z    detrumpezvous      1746561377
# 18       1750084921   2025-06-16T14:42:01Z            yaron      1750084921
# 20       1746529342   2025-05-06T11:02:22Z    detrumpezvous      1746529342
#
#    last_updated_datetime  ... water-hardness_100g choline_100g  \
# 9   2025-06-23T16:10:17Z  ...                 NaN          NaN
# 12  2025-04-10T00:11:24Z  ...                 NaN          NaN
# 13  2025-05-06T19:56:17Z  ...                 NaN          NaN
# 18  2025-06-16T14:42:01Z  ...                 NaN          NaN
# 20  2025-05-06T11:02:22Z  ...                 NaN          NaN
#
#    phylloquinone_100g beta-glucan_100g inositol_100g carnitine_100g  \
# 9                 NaN              NaN           NaN            NaN
# 12                NaN              NaN           NaN            NaN
# 13                NaN              NaN           NaN            NaN
# 18                NaN              NaN           NaN            NaN
# 20                NaN              NaN           NaN            NaN
#
#    sulphate_100g nitrate_100g acidity_100g carbohydrates-total_100g
# 9            NaN          NaN          NaN                      NaN
# 12           NaN          NaN          NaN                      NaN
# 13           NaN          NaN          NaN                      NaN
# 18           NaN          NaN          NaN                      NaN
# 20           NaN          NaN          NaN                      NaN
#
# [5 rows x 215 columns]

# %%
snacks = snacks.copy()
max_drop = int(len(snacks) * 0.20)
max_drop
snacks.drop(columns=snacks.columns[snacks.isna().sum() > max_drop], inplace=True)
snacks.head()
# Out:
#     code                                                url  \
# 9     10  http://world-en.openfoodfacts.org/product/0000...
# 12    13  http://world-en.openfoodfacts.org/product/0000...
# 13    15  http://world-en.openfoodfacts.org/product/0000...
# 18    20  http://world-en.openfoodfacts.org/product/0000...
# 20    22  http://world-en.openfoodfacts.org/product/0000...
#
#                        creator   created_t      created_datetime  \
# 9                     jeanbono  1476947941  2016-10-20T07:19:01Z
# 12                   jeff-krab  1553970319  2019-03-30T18:25:19Z
# 13  openfoodfacts-contributors  1523810594  2018-04-15T16:43:14Z
# 18  openfoodfacts-contributors  1536930846  2018-09-14T13:14:06Z
# 20  openfoodfacts-contributors  1614525537  2021-02-28T15:18:57Z
#
#     last_modified_t last_modified_datetime last_modified_by  last_updated_t  \
# 9        1750695017   2025-06-23T16:10:17Z     smoothie-app      1750695017
# 12       1744243884   2025-04-10T00:11:24Z           maldan      1744243884
# 13       1746561377   2025-05-06T19:56:17Z    detrumpezvous      1746561377
# 18       1750084921   2025-06-16T14:42:01Z            yaron      1750084921
# 20       1746529342   2025-05-06T11:02:22Z    detrumpezvous      1746529342
#
#    last_updated_datetime  ... fat_100g saturated-fat_100g carbohydrates_100g  \
# 9   2025-06-23T16:10:17Z  ...     1.40                NaN                4.5
# 12  2025-04-10T00:11:24Z  ...    13.00               6.70               15.0
# 13  2025-05-06T19:56:17Z  ...    24.00               6.00               54.0
# 18  2025-06-16T14:42:01Z  ...     5.71                NaN               31.4
# 20  2025-05-06T11:02:22Z  ...    16.70               6.48               35.2
#
#    sugars_100g fiber_100g proteins_100g salt_100g sodium_100g  \
# 9          NaN        NaN          83.0       NaN         NaN
# 12        3.60        NaN          11.0    0.0625       0.025
# 13       31.00        1.4           6.4    0.4800       0.192
# 18        8.57       14.3          57.1    1.7900       0.714
# 20        1.85       18.5          37.0    0.8800       0.352
#
#    fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 9                                           22.666667
# 12                                           0.000000
# 13                                          16.250000
# 18                                          56.346154
# 20                                           1.750000
#
#    nutrition-score-fr_100g
# 9                      NaN
# 12                     3.0
# 13                    20.0
# 18                     NaN
# 20                     9.0
#
# [5 rows x 47 columns]

# %%
snacks.isna().sum().sort_values(ascending=False).plot(
  kind="bar"
)
# Out:
# <Axes: >

# %%
snacks.drop(columns=[
    "code", "url", "created_t", "created_datetime", "last_modified_t", 
    "last_modified_datetime", "last_modified_by", "last_updated_t", "last_updated_datetime"
], inplace=True)
snacks.head()
# Out:
#                        creator            product_name  \
# 9                     jeanbono                     xxx
# 12                   jeff-krab  Powdered peanut butter
# 13  openfoodfacts-contributors    Madeleines ChocoLait
# 18  openfoodfacts-contributors  Nesquik moins de sucre
# 20  openfoodfacts-contributors  Farandole de madeleine
#
#                                            categories  \
# 9   Beverages and beverages preparations, Beverage...
# 12  Snacks, Meals, Rice dishes, Risottos, Powder p...
# 13  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
# 18  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
# 20  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
#
#                                       categories_tags  \
# 9   en:beverages-and-beverages-preparations,en:bev...
# 12  en:snacks,en:meals,en:rice-dishes,en:risottos,...
# 13  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
#
#                                         categories_en            countries  \
# 9   Beverages and beverages preparations,Beverages...                   DE
# 12  Snacks,Meals,Rice dishes,Risottos,Powder-peanu...       en:Switzerland
# 13  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...               France
# 18  Snacks,Sweet snacks,Biscuits and cakes,Cakes,P...  Frankreich, Germany
# 20  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...               Brasil
#
#           countries_tags    countries_en  \
# 9             en:germany         Germany
# 12        en:switzerland     Switzerland
# 13             en:france          France
# 18  en:france,en:germany  France,Germany
# 20             en:brazil          Brazil
#
#                                      ingredients_text  \
# 9   Farine de blÃ© 33%, sucre, huile de colza, Å“u...
# 12  Water, Leptospermum Scoparium Mel (Manuka Hone...
# 13  Farine de blÃ© 27%, chocolat au lait 18% (sucr...
# 18  Nuts (Peanuts, Almonds), Prebiotic Blend (Tapi...
# 20  Madeleines ChocoNoir - Madeleines nappÃ©es de ...
#
#                                      ingredients_tags  ... fat_100g  \
# 9   en:wheat-flour,en:cereal,en:flour,en:wheat,en:...  ...     1.40
# 12  en:water,en:leptospermum-scoparium-mel,en:sodi...  ...    13.00
# 13  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...  ...    24.00
# 18  en:nut,en:prebiotic-blend,en:protein-blend,en:...  ...     5.71
# 20  fr:madeleines-choconoir,fr:madeleines-nappees-...  ...    16.70
#
#    saturated-fat_100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 9                 NaN                 4.5          NaN         NaN
# 12               6.70                15.0         3.60         NaN
# 13               6.00                54.0        31.00         1.4
# 18                NaN                31.4         8.57        14.3
# 20               6.48                35.2         1.85        18.5
#
#    proteins_100g  salt_100g sodium_100g  \
# 9           83.0        NaN         NaN
# 12          11.0     0.0625       0.025
# 13           6.4     0.4800       0.192
# 18          57.1     1.7900       0.714
# 20          37.0     0.8800       0.352
#
#    fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 9                                           22.666667
# 12                                           0.000000
# 13                                          16.250000
# 18                                          56.346154
# 20                                           1.750000
#
#    nutrition-score-fr_100g
# 9                      NaN
# 12                     3.0
# 13                    20.0
# 18                     NaN
# 20                     9.0
#
# [5 rows x 38 columns]

# %%
snacks.isna().sum().sort_values(ascending=False).plot(
  kind="bar"
)
# Out:
# <Axes: >

# %%
snacks.head()
# Out:
#                        creator            product_name  \
# 9                     jeanbono                     xxx
# 12                   jeff-krab  Powdered peanut butter
# 13  openfoodfacts-contributors    Madeleines ChocoLait
# 18  openfoodfacts-contributors  Nesquik moins de sucre
# 20  openfoodfacts-contributors  Farandole de madeleine
#
#                                            categories  \
# 9   Beverages and beverages preparations, Beverage...
# 12  Snacks, Meals, Rice dishes, Risottos, Powder p...
# 13  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
# 18  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
# 20  Snacks, Snacks sucrÃ©s, Biscuits et gÃ¢teaux, ...
#
#                                       categories_tags  \
# 9   en:beverages-and-beverages-preparations,en:bev...
# 12  en:snacks,en:meals,en:rice-dishes,en:risottos,...
# 13  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 18  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
# 20  en:snacks,en:sweet-snacks,en:biscuits-and-cake...
#
#                                         categories_en            countries  \
# 9   Beverages and beverages preparations,Beverages...                   DE
# 12  Snacks,Meals,Rice dishes,Risottos,Powder-peanu...       en:Switzerland
# 13  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...               France
# 18  Snacks,Sweet snacks,Biscuits and cakes,Cakes,P...  Frankreich, Germany
# 20  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...               Brasil
#
#           countries_tags    countries_en  \
# 9             en:germany         Germany
# 12        en:switzerland     Switzerland
# 13             en:france          France
# 18  en:france,en:germany  France,Germany
# 20             en:brazil          Brazil
#
#                                      ingredients_text  \
# 9   Farine de blÃ© 33%, sucre, huile de colza, Å“u...
# 12  Water, Leptospermum Scoparium Mel (Manuka Hone...
# 13  Farine de blÃ© 27%, chocolat au lait 18% (sucr...
# 18  Nuts (Peanuts, Almonds), Prebiotic Blend (Tapi...
# 20  Madeleines ChocoNoir - Madeleines nappÃ©es de ...
#
#                                      ingredients_tags  ... fat_100g  \
# 9   en:wheat-flour,en:cereal,en:flour,en:wheat,en:...  ...     1.40
# 12  en:water,en:leptospermum-scoparium-mel,en:sodi...  ...    13.00
# 13  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...  ...    24.00
# 18  en:nut,en:prebiotic-blend,en:protein-blend,en:...  ...     5.71
# 20  fr:madeleines-choconoir,fr:madeleines-nappees-...  ...    16.70
#
#    saturated-fat_100g  carbohydrates_100g  sugars_100g  fiber_100g  \
# 9                 NaN                 4.5          NaN         NaN
# 12               6.70                15.0         3.60         NaN
# 13               6.00                54.0        31.00         1.4
# 18                NaN                31.4         8.57        14.3
# 20               6.48                35.2         1.85        18.5
#
#    proteins_100g  salt_100g sodium_100g  \
# 9           83.0        NaN         NaN
# 12          11.0     0.0625       0.025
# 13           6.4     0.4800       0.192
# 18          57.1     1.7900       0.714
# 20          37.0     0.8800       0.352
#
#    fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 9                                           22.666667
# 12                                           0.000000
# 13                                          16.250000
# 18                                          56.346154
# 20                                           1.750000
#
#    nutrition-score-fr_100g
# 9                      NaN
# 12                     3.0
# 13                    20.0
# 18                     NaN
# 20                     9.0
#
# [5 rows x 38 columns]

# %%
#drop similar columns categories, categories_tags, countries, countries_tags,main_category,states, states_tags
snacks.drop(columns=["categories", "categories_tags", "countries", "countries_tags", "main_category", "states", "states_tags"], inplace=True)
snacks.head()
# Out:
#                        creator            product_name  \
# 9                     jeanbono                     xxx
# 12                   jeff-krab  Powdered peanut butter
# 13  openfoodfacts-contributors    Madeleines ChocoLait
# 18  openfoodfacts-contributors  Nesquik moins de sucre
# 20  openfoodfacts-contributors  Farandole de madeleine
#
#                                         categories_en    countries_en  \
# 9   Beverages and beverages preparations,Beverages...         Germany
# 12  Snacks,Meals,Rice dishes,Risottos,Powder-peanu...     Switzerland
# 13  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...          France
# 18  Snacks,Sweet snacks,Biscuits and cakes,Cakes,P...  France,Germany
# 20  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...          Brazil
#
#                                      ingredients_text  \
# 9   Farine de blÃ© 33%, sucre, huile de colza, Å“u...
# 12  Water, Leptospermum Scoparium Mel (Manuka Hone...
# 13  Farine de blÃ© 27%, chocolat au lait 18% (sucr...
# 18  Nuts (Peanuts, Almonds), Prebiotic Blend (Tapi...
# 20  Madeleines ChocoNoir - Madeleines nappÃ©es de ...
#
#                                      ingredients_tags  \
# 9   en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 12  en:water,en:leptospermum-scoparium-mel,en:sodi...
# 13  en:wheat-flour,en:cereal,en:flour,en:wheat,en:...
# 18  en:nut,en:prebiotic-blend,en:protein-blend,en:...
# 20  fr:madeleines-choconoir,fr:madeleines-nappees-...
#
#                             ingredients_analysis_tags     serving_size  \
# 9   en:palm-oil-free,en:non-vegan,en:vegetarian-st...            17,6g
# 12  en:may-contain-palm-oil,en:non-vegan,en:vegeta...               0g
# 13  en:palm-oil-free,en:non-vegan,en:maybe-vegetarian            21,6g
# 18  en:palm-oil-content-unknown,en:vegan-status-un...  2 scoops (35 g)
# 20  en:palm-oil-content-unknown,en:non-vegan,en:ve...              54g
#
#     serving_quantity  additives_n  ...  fat_100g saturated-fat_100g  \
# 9               17.6          3.0  ...      1.40                NaN
# 12               0.0          0.0  ...     13.00               6.70
# 13              21.6          6.0  ...     24.00               6.00
# 18              35.0          0.0  ...      5.71                NaN
# 20              54.0          6.0  ...     16.70               6.48
#
#     carbohydrates_100g sugars_100g fiber_100g proteins_100g salt_100g  \
# 9                  4.5         NaN        NaN          83.0       NaN
# 12                15.0        3.60        NaN          11.0    0.0625
# 13                54.0       31.00        1.4           6.4    0.4800
# 18                31.4        8.57       14.3          57.1    1.7900
# 20                35.2        1.85       18.5          37.0    0.8800
#
#     sodium_100g fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 9           NaN                                          22.666667
# 12        0.025                                           0.000000
# 13        0.192                                          16.250000
# 18        0.714                                          56.346154
# 20        0.352                                           1.750000
#
#     nutrition-score-fr_100g
# 9                       NaN
# 12                      3.0
# 13                     20.0
# 18                      NaN
# 20                      9.0
#
# [5 rows x 31 columns]

# %%
snacks.isna().sum().sort_values(ascending=False).plot(
  kind="bar"
)
# Out:
# <Axes: >

# %%
snacks.columns
# Out:
# Index(['creator', 'product_name', 'categories_en', 'countries_en',
#        'ingredients_text', 'ingredients_tags', 'ingredients_analysis_tags',
#        'serving_size', 'serving_quantity', 'additives_n', 'nutriscore_score',
#        'nutriscore_grade', 'nova_group', 'pnns_groups_1', 'pnns_groups_2',
#        'states_en', 'nutrient_levels_tags', 'completeness', 'main_category_en',
#        'energy-kcal_100g', 'energy_100g', 'fat_100g', 'saturated-fat_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g',
#        'fruits-vegetables-nuts-estimate-from-ingredients_100g',
#        'nutrition-score-fr_100g'],
#       dtype='object')

# %%
snacks.isna().sum()
# Out:
# creator                                                     0
# product_name                                              107
# categories_en                                               0
# countries_en                                               11
# ingredients_text                                         1065
# ingredients_tags                                         1065
# ingredients_analysis_tags                                1024
# serving_size                                             1338
# serving_quantity                                         1382
# additives_n                                              1065
# nutriscore_score                                         1100
# nutriscore_grade                                            0
# nova_group                                               1171
# pnns_groups_1                                               0
# pnns_groups_2                                               0
# states_en                                                   0
# nutrient_levels_tags                                      465
# completeness                                                0
# main_category_en                                            0
# energy-kcal_100g                                          538
# energy_100g                                               487
# fat_100g                                                  477
# saturated-fat_100g                                       1169
# carbohydrates_100g                                        502
# sugars_100g                                               714
# fiber_100g                                               1934
# proteins_100g                                             485
# salt_100g                                                 655
# sodium_100g                                               655
# fruits-vegetables-nuts-estimate-from-ingredients_100g    1065
# nutrition-score-fr_100g                                  1100
# dtype: int64

# %%
snacks["product_name"]=snacks["product_name"].fillna("Unknown")
snacks["countries_en"]=snacks["countries_en"].fillna("Unknown")
snacks.isna().sum()
# Out:
# creator                                                     0
# product_name                                                0
# categories_en                                               0
# countries_en                                                0
# ingredients_text                                         1065
# ingredients_tags                                         1065
# ingredients_analysis_tags                                1024
# serving_size                                             1338
# serving_quantity                                         1382
# additives_n                                              1065
# nutriscore_score                                         1100
# nutriscore_grade                                            0
# nova_group                                               1171
# pnns_groups_1                                               0
# pnns_groups_2                                               0
# states_en                                                   0
# nutrient_levels_tags                                      465
# completeness                                                0
# main_category_en                                            0
# energy-kcal_100g                                          538
# energy_100g                                               487
# fat_100g                                                  477
# saturated-fat_100g                                       1169
# carbohydrates_100g                                        502
# sugars_100g                                               714
# fiber_100g                                               1934
# proteins_100g                                             485
# salt_100g                                                 655
# sodium_100g                                               655
# fruits-vegetables-nuts-estimate-from-ingredients_100g    1065
# nutrition-score-fr_100g                                  1100
# dtype: int64

# %%
#remove the following ingredients_text                                         1065
# ingredients_tags                                         1065
# ingredients_analysis_tags                                1024
# serving_size                                             1338
# serving_quantity  

snacks.drop(columns=["ingredients_text", "ingredients_tags", "ingredients_analysis_tags", "serving_size", "serving_quantity"], inplace=True)
snacks.head()
# Out:
#                        creator            product_name  \
# 9                     jeanbono                     xxx
# 12                   jeff-krab  Powdered peanut butter
# 13  openfoodfacts-contributors    Madeleines ChocoLait
# 18  openfoodfacts-contributors  Nesquik moins de sucre
# 20  openfoodfacts-contributors  Farandole de madeleine
#
#                                         categories_en    countries_en  \
# 9   Beverages and beverages preparations,Beverages...         Germany
# 12  Snacks,Meals,Rice dishes,Risottos,Powder-peanu...     Switzerland
# 13  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...          France
# 18  Snacks,Sweet snacks,Biscuits and cakes,Cakes,P...  France,Germany
# 20  Snacks,Sweet snacks,Biscuits and cakes,Cakes,C...          Brazil
#
#     additives_n  nutriscore_score nutriscore_grade  nova_group  \
# 9           3.0               NaN          unknown         4.0
# 12          0.0               3.0                c         NaN
# 13          6.0              20.0                e         4.0
# 18          0.0               NaN          unknown         4.0
# 20          6.0               9.0                c         4.0
#
#       pnns_groups_1        pnns_groups_2  ... fat_100g saturated-fat_100g  \
# 9         Beverages  Sweetened beverages  ...     1.40                NaN
# 12  Composite foods       One-dish meals  ...    13.00               6.70
# 13    Sugary snacks   Biscuits and cakes  ...    24.00               6.00
# 18    Sugary snacks   Biscuits and cakes  ...     5.71                NaN
# 20    Sugary snacks   Biscuits and cakes  ...    16.70               6.48
#
#     carbohydrates_100g sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 9                  4.5         NaN         NaN           83.0        NaN
# 12                15.0        3.60         NaN           11.0     0.0625
# 13                54.0       31.00         1.4            6.4     0.4800
# 18                31.4        8.57        14.3           57.1     1.7900
# 20                35.2        1.85        18.5           37.0     0.8800
#
#     sodium_100g  fruits-vegetables-nuts-estimate-from-ingredients_100g  \
# 9           NaN                                          22.666667
# 12        0.025                                           0.000000
# 13        0.192                                          16.250000
# 18        0.714                                          56.346154
# 20        0.352                                           1.750000
#
#     nutrition-score-fr_100g
# 9                       NaN
# 12                      3.0
# 13                     20.0
# 18                      NaN
# 20                      9.0
#
# [5 rows x 26 columns]

# %%
snacks["nutriscore_grade"]=snacks["nutriscore_grade"].fillna("unknown")

# %%
#drop additives_n, nutriscore_score, nutrient_levels_tags

# %%
snacks["nova_group"]=snacks["nova_group"].fillna(snacks["nova_group"].mode()[0])

# %%
# snacks["energy-kcal_100g"].plot(
#   kind="hist", bins=50
# )

snacks = snacks[snacks["energy-kcal_100g"] < 900]
snacks["energy-kcal_100g"].plot(
  kind="hist", bins=50
)
# nacks["energy-kcal_100g"]=snacks["energy-kcal_100g"].fillna(snacks["energy-kcal_100g"].mean())
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks = snacks[snacks["energy_100g"] <= 4000]
snacks["energy_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9185 entries, 9 to 99944
# Data columns (total 26 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   creator                                                9185 non-null   object
#  1   product_name                                           9185 non-null   object
#  2   categories_en                                          9185 non-null   object
#  3   countries_en                                           9185 non-null   object
#  4   additives_n                                            8359 non-null   float64
#  5   nutriscore_score                                       8546 non-null   float64
#  6   nutriscore_grade                                       9185 non-null   object
#  7   nova_group                                             9185 non-null   float64
#  8   pnns_groups_1                                          9185 non-null   object
#  9   pnns_groups_2                                          9185 non-null   object
#  10  states_en                                              9185 non-null   object
#  11  nutrient_levels_tags                                   9174 non-null   object
#  12  completeness                                           9185 non-null   float64
#  13  main_category_en                                       9185 non-null   object
#  14  energy-kcal_100g                                       9185 non-null   float64
#  15  energy_100g                                            9185 non-null   float64
#  16  fat_100g                                               9169 non-null   float64
#  17  saturated-fat_100g                                     8479 non-null   float64
#  18  carbohydrates_100g                                     9147 non-null   float64
#  19  sugars_100g                                            8936 non-null   float64
#  20  fiber_100g                                             7717 non-null   float64
#  21  proteins_100g                                          9166 non-null   float64
#  22  salt_100g                                              8989 non-null   float64
#  23  sodium_100g                                            8989 non-null   float64
#  24  fruits-vegetables-nuts-estimate-from-ingredients_100g  8359 non-null   float64
#  25  nutrition-score-fr_100g                                8546 non-null   float64
# dtypes: float64(16), object(10)
# memory usage: 1.9+ MB

# %%
snacks = snacks[snacks["fat_100g"] <= 100]

# Now the plot will look correct
snacks["fat_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# 2. The Golden Rule: Saturated Fat must be <= Total Fat
# This removes rows where the math doesn't add up
snacks = snacks[snacks["saturated-fat_100g"] <= snacks["fat_100g"]]

# Now plot again to be sure
snacks["saturated-fat_100g"].plot(kind="hist", bins=50)

snacks["saturated-fat_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks=snacks[snacks["carbohydrates_100g"] <= 100]

snacks["carbohydrates_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks=snacks[snacks["sugars_100g"] <= 100]

snacks["sugars_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# snacks["fiber_100g"].plot(kind="hist", bins=50)
print(snacks[snacks["fiber_100g"] > 40][["product_name", "fiber_100g"]])
# Out:
#                                             product_name  fiber_100g
# 10835                                     Å’ufs PralinÃ©   57.000000
# 17068                                     Jammie Dodgers  100.000000
# 21263  Î£ÎºÎ±Î½Î´Î¹Î½Î±Î²Î¹ÎºÎ­Ï‚ Î¦ÏÏ…Î³Î±Î½Î¹Î­Ï‚ ...   47.200000
# 34596                Kettle cooked original potato chips   67.857143
# 51285   World classics trading company, nonpareil capers  100.000000
# 58158                            Organic Golden Cake Mix   47.368421
# 73032                           Brownies Chocolate Fudge   48.000000

# %%
snacks = snacks[snacks["fiber_100g"] <= 40]

# Calculate the 25th and 75th percentiles
Q1 = snacks['fiber_100g'].quantile(0.25)
Q3 = snacks['fiber_100g'].quantile(0.75)
IQR = Q3 - Q1

# Define "outliers" as anything outside 1.5 times the IQR
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Keep only rows within the bounds
snacks = snacks[(snacks['fiber_100g'] >= lower_bound) & (snacks['fiber_100g'] <= upper_bound)]

# 2. Check the histogram again - it should look completely normal now
snacks["fiber_100g"].plot(kind="hist", bins=50, title="Clean Fiber Distribution")
# Out:
# <Axes: title={'center': 'Clean Fiber Distribution'}, ylabel='Frequency'>

# %%
snacks = snacks[snacks["proteins_100g"] <= 100]
snacks["proteins_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks= snacks[snacks["salt_100g"] <= 100]
snacks["salt_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks = snacks[snacks["fruits-vegetables-nuts-estimate-from-ingredients_100g"] <= 100]
snacks["fruits-vegetables-nuts-estimate-from-ingredients_100g"].plot(kind="hist", bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
snacks = snacks[(snacks["nutrition-score-fr_100g"] >= -15) & (snacks["nutrition-score-fr_100g"] <= 40)]

# Plot again to confirm
snacks["nutrition-score-fr_100g"].plot(kind="hist", bins=50, title="Clean Nutri-Score Distribution")
# Out:
# <Axes: title={'center': 'Clean Nutri-Score Distribution'}, ylabel='Frequency'>

# %%
# Calculate expected energy (kJ)
expected_energy = (snacks['fat_100g'] * 37) + (snacks['carbohydrates_100g'] * 17) + (snacks['proteins_100g'] * 17)

# Filter out rows where the difference is huge (e.g., > 20%)
# This catches subtle typos like 10g fat becoming 100g fat
snacks['energy_diff'] = abs(snacks['energy_100g'] - expected_energy)
snacks = snacks[snacks['energy_diff'] < 500] # Allow 500kJ margin of error

# %%
# Clean text columns to merge duplicates
# snacks['brands'] = snacks['brands'].str.lower().str.strip()
# snacks['categories_tags'] = snacks['categories_tags'].str.lower().str.strip()

# %%
def wrangle(filepath):
  df = pd.read_csv(filepath, sep="\t", low_memory=False)
  
  # Select the snacks 
  snacks = df[df["categories_tags"].str.contains("Snack", case=False, na=False)].copy()
  
  #drop the columns with > 20% missing
  max_drop = int(len(snacks) * 0.20)
  snacks.drop(columns=snacks.columns[snacks.isna().sum() > max_drop], inplace=True)
  
  # drop code, url & time columns
  snacks.drop(columns=[
    "code", "url", "created_t", "created_datetime", "last_modified_t", 
    "last_modified_datetime", "last_modified_by", "last_updated_t", "last_updated_datetime"
], inplace=True)
  
  # drop duplicate country & categorie columns
  snacks.drop(columns=["categories", "categories_tags", "countries", "countries_tags", "main_category", "states", "states_tags"], inplace=True)
  
  # drop the ingredients and serving columns
  snacks.drop(columns=["ingredients_text", "ingredients_tags", "ingredients_analysis_tags", "serving_size", "serving_quantity"], inplace=True)


  # Replace missing product & country names with "Unknown"
  snacks["product_name"]=snacks["product_name"].fillna("Unknown")
  snacks["countries_en"]=snacks["countries_en"].fillna("Unknown")

  # Replace nutriscore_grade's missing vale with unknown
  snacks["nutriscore_grade"]=snacks["nutriscore_grade"].fillna("unknown")

  # replace missing nova_group(food_processed) with the most common value (mode)
  snacks["nova_group"]=snacks["nova_group"].fillna(snacks["nova_group"].mode()[0])

  # reomve rows with energy_kcal_100g > 900  
  snacks = snacks[snacks["energy-kcal_100g"] <= 900]

  # reomve rows with energy_100g > 4000
  snacks = snacks[snacks["energy_100g"] <= 4000]

  # reomve rows with fat_100g > 100
  snacks = snacks[snacks["fat_100g"] <= 100]

  # Saturated Fat must be <= Total Fat
  # This removes rows where the math doesn't add up
  snacks = snacks[snacks["saturated-fat_100g"] <= snacks["fat_100g"]]

  # reomve rows with carbohydrates_100g > 100
  snacks=snacks[snacks["carbohydrates_100g"] <= 100]

  # reomve rows with sugars_100g > 100
  snacks=snacks[snacks["sugars_100g"] <= 100]

  # reomve rows with fiber_100g > 40
  snacks = snacks[snacks["fiber_100g"] <= 40]

  # reomve rows with proteins_100g > 100
  snacks = snacks[snacks["proteins_100g"] <= 100]

  # reomve rows with salt_100g > 100
  snacks= snacks[snacks["salt_100g"] <= 100]

  # reomve rows with fruits-vegetables-nuts-estimate-from-ingredients_100g > 100
  snacks = snacks[snacks["fruits-vegetables-nuts-estimate-from-ingredients_100g"] <= 100]

  # reomve rows with nutrition-score-fr_100g < -15 or > 40
  snacks = snacks[(snacks["nutrition-score-fr_100g"] >= -15) & (snacks["nutrition-score-fr_100g"] <= 40)]
  
  return snacks

# %%
snacks.isna().sum()
# Out:
# creator                                                  0
# product_name                                             0
# categories_en                                            0
# countries_en                                             0
# additives_n                                              0
# nutriscore_score                                         0
# nutriscore_grade                                         0
# nova_group                                               0
# pnns_groups_1                                            0
# pnns_groups_2                                            0
# states_en                                                0
# nutrient_levels_tags                                     0
# completeness                                             0
# main_category_en                                         0
# energy-kcal_100g                                         0
# energy_100g                                              0
# fat_100g                                                 0
# saturated-fat_100g                                       0
# carbohydrates_100g                                       0
# sugars_100g                                              0
# fiber_100g                                               0
# proteins_100g                                            0
# salt_100g                                                0
# sodium_100g                                              0
# fruits-vegetables-nuts-estimate-from-ingredients_100g    0
# nutrition-score-fr_100g                                  0
# dtype: int64
